# %%
import spotipy
from dotenv import load_dotenv
from spotipy.oauth2 import SpotifyOAuth

from music_analysis import REPO_ROOT

load_dotenv(REPO_ROOT / ".env")

import spotipy
from spotipy.oauth2 import SpotifyOAuth

scope = "user-library-read"
scope = "user-top-read"


sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope))

# %%
results = sp.current_user_saved_tracks()
# Out:
# Enter the URL you were redirected to:  http://127.0.0.1:9090
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/spotipy/oauth2.py:559, in SpotifyOAuth.get_access_token(self, code, as_dict, check_cache)
#     551 response = self._session.post(
#     552     self.OAUTH_TOKEN_URL,
#     553     data=payload,
#    (...)
#     557     timeout=self.requests_timeout,
#     558 )
# --> 559 response.raise_for_status()
#     560 token_info = response.json()
#
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://accounts.spotify.com/api/token
#
# During handling of the above exception, another exception occurred:
#
# SpotifyOauthError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 results = sp.current_user_saved_tracks()
#
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/spotipy/client.py:1286, in Spotify.current_user_saved_tracks(self, limit, offset, market)
#    1276 def current_user_saved_tracks(self, limit=20, offset=0, market=None):
#    1277     """ Gets a list of the tracks saved in the current authorized user's
#    1278         "Your Music" library
#    1279
#    (...)
#    1284
#    1285     """
# -> 1286     return self._get("me/tracks", limit=limit, offset=offset, market=market)
#
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/spotipy/client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/spotipy/client.py:247, in Spotify._internal_call(self, method, url, payload, params)
#     245 if not url.startswith("http"):
#     246     url = self.prefix + url
# --> 247 headers = self._auth_headers()
#     249 if "content_type" in args["params"]:
#     250     headers["Content-Type"] = args["params"]["content_type"]
#
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/spotipy/client.py:238, in Spotify._auth_headers(self)
#     236     return {}
#     237 try:
# --> 238     token = self.auth_manager.get_access_token(as_dict=False)
#     239 except TypeError:
#     240     token = self.auth_manager.get_access_token()
#
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/spotipy/oauth2.py:565, in SpotifyOAuth.get_access_token(self, code, as_dict, check_cache)
#     563     return token_info if as_dict else token_info["access_token"]
#     564 except requests.exceptions.HTTPError as http_error:
# --> 565     self._handle_oauth_error(http_error)
#
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/spotipy/oauth2.py:146, in SpotifyAuthBase._handle_oauth_error(self, http_error)
#     143     error = response.text or None
#     144     error_description = None
# --> 146 raise SpotifyOauthError(
#     147     'error: {0}, error_description: {1}'.format(
#     148         error, error_description
#     149     ),
#     150     error=error,
#     151     error_description=error_description
#     152 )
#
# SpotifyOauthError: error: invalid_request, error_description: code must be supplied

# %%
for idx, item in enumerate(results['items']):
    track = item['track']
    print(idx, track['artists'][0]['name'], " – ", track['name'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 16
#      12 scope = "user-library-read"
#      14 sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope))
# ---> 16 results = sp.current_user_saved_tracks()
#      17 for idx, item in enumerate(results['items']):
#      18     track = item['track']
#
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/spotipy/client.py:1286, in Spotify.current_user_saved_tracks(self, limit, offset, market)
#    1276 def current_user_saved_tracks(self, limit=20, offset=0, market=None):
#    1277     """ Gets a list of the tracks saved in the current authorized user's
#    1278         "Your Music" library
#    1279
#    (...)
#    1284
#    1285     """
# -> 1286     return self._get("me/tracks", limit=limit, offset=offset, market=market)
#
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/spotipy/client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/spotipy/client.py:247, in Spotify._internal_call(self, method, url, payload, params)
#     245 if not url.startswith("http"):
#     246     url = self.prefix + url
# --> 247 headers = self._auth_headers()
#     249 if "content_type" in args["params"]:
#     250     headers["Content-Type"] = args["params"]["content_type"]
#
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/spotipy/client.py:238, in Spotify._auth_headers(self)
#     236     return {}
#     237 try:
# --> 238     token = self.auth_manager.get_access_token(as_dict=False)
#     239 except TypeError:
#     240     token = self.auth_manager.get_access_token()
#
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/spotipy/oauth2.py:535, in SpotifyOAuth.get_access_token(self, code, as_dict, check_cache)
#     528             token_info = self.refresh_access_token(
#     529                 token_info["refresh_token"]
#     530             )
#     531         return token_info if as_dict else token_info["access_token"]
#     533 payload = {
#     534     "redirect_uri": self.redirect_uri,
# --> 535     "code": code or self.get_auth_response(),
#     536     "grant_type": "authorization_code",
#     537 }
#     538 if self.scope:
#     539     payload["scope"] = self.scope
#
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/spotipy/oauth2.py:499, in SpotifyOAuth.get_auth_response(self, open_browser)
#     491     else:
#     492         logger.warning('Using `%s` as redirect URI without a port. '
#     493                        'Specify a port (e.g. `%s:8080`) to allow '
#     494                        'automatic retrieval of authentication code '
#     495                        'instead of having to copy and paste '
#     496                        'the URL your browser is redirected to.',
#     497                        redirect_host, redirect_host)
# --> 499 return self._get_auth_response_interactive(open_browser=open_browser)
#
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/spotipy/oauth2.py:450, in SpotifyOAuth._get_auth_response_interactive(self, open_browser)
#     445     url = self.get_authorize_url()
#     446     prompt = (
#     447         "Go to the following URL: {}\n"
#     448         "Enter the URL you were redirected to: ".format(url)
#     449     )
# --> 450 response = self._get_user_input(prompt)
#     451 state, code = SpotifyOAuth.parse_auth_response_url(response)
#     452 if self.state is not None and self.state != state:
#
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/spotipy/oauth2.py:117, in SpotifyAuthBase._get_user_input(prompt)
#     115     return raw_input(prompt)
#     116 except NameError:
# --> 117     return input(prompt)
#
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~/Documents/Workspace/Github/music_analysis/.venv/lib/python3.10/site-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
